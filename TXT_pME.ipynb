# %% [markdown]
# ## Para leer contenido de archivo

# %%
a = open('C:/Users/m.pirela.escobar/OneDrive - Accenture/Galicia/pME/RESFIS.FULL.txt')
mensaje = a.read()
f.close()

# %% [markdown]
# ## Para eliminar espacios en blanco al final y generar nuevo archivo

# %%
with open('C:/Users/m.pirela.escobar/OneDrive - Accenture/Galicia/pME/RESFIS.FULL.txt') as f:
    mylist = [line.replace('\x00', '') for line in f]
    b = open('C:/Users/m.pirela.escobar/OneDrive - Accenture/Galicia/pME/RESFIS.FULL2.txt', 'w')
    b.writelines(mylist)
    b.close

# %% [markdown]
# ## Para ver contenido de archivo nuevo

# %%
a = open('C:/Users/m.pirela.escobar/OneDrive - Accenture/Galicia/NV_MDP/NV/PFISICAS_3.txt')
mensaje = a.read()
print(mensaje)
f.close()
# Out:
# 0000006151ACEVEDO 0HI3 0000000006151                          ACEVEDO                       HILDA                         DU  000424895700000000000000001935112608000080FC999 99500000000000000000000000000000000000000000 0000000N0000000000000000000                                                                                                                                                                                             0000                                                                    00000+000,000000+000,0000000000000000000000000              00000000                                                                         0000000000000000                                                                                                                        205219860512100716000                              0000000000        00  000000000000000{000000000000000000000000000000000000000000{00000000000000000{00000000000000000{002110000000000000      00007               00
# ...

# %% [markdown]
# ## Para archivo de personas Jurídicas

# %%
with open('C:/Users/m.pirela.escobar/OneDrive - Accenture/Galicia/NV_MDP/E-MAIL_Full.txt') as f:
    mylist = [line.rstrip() for line in f]
    b = open('C:/Users/m.pirela.escobar/OneDrive - Accenture/Galicia/NV_MDP/NV/E-MAIL_Full_sin_nulos.txt', 'w')
    b.writelines(mylist)
    b.close

# %%
with open('C:/Users/m.pirela.escobar/OneDrive - Accenture/Galicia/pME/RESFIS.FULL_1.txt') as myfile:
    total_lines = sum(1 for line in myfile)

print(total_lines)
# Out:
# 159814
